# %%
from multiprocessing import Process
import threading
import time
z = 0
v = 0
def aa():
    while True:
        global v,z
        v += 1
        if v == 50000:
            z = 1
            break
        else:
            print('v: ',v,",",z)
    
def bb():
    for i in range(20):
        if z == 1:
            print('time',times)
            break
        else:
            times = i
            print("time",times)
            time.sleep(1)
            
aa_t = threading.Thread(target = aa)
bb_t = threading.Thread(target = bb)
# aa_t = Process(target = aa)
# bb_t = Process(target = bb)
aa_t.start()
bb_t.start()
# Out:
# v: time 1 , 0
# v:  2 , 0
# v:  3 , 0
# v:  4 , 0
# v:  5  0
# z:, 0
# v:  6 , 0
# v:  7 , 0
# v:  8 , 0
# v:  9 , 0
# v:  10 , 0
# v:  11 , 0
# v:  12 , 0
# v:  13 , 0
# v:  14 , 0
# v:  15 , 0
# v:  16 , 0
# v:  17 , 0
# v:  18 , 0
# v:  19 , 0
# v:  20 ,  0
# v:  21 , 0
# v:  22 , 0
# v:  23 , 0
# v:  24 , 0
# v:  25 , 0
# v:  26 , 0
# v:  27 , 0
# v:  28 , 0
# v:  29 , 0
# v:  30 0
# , 0
# v:  31 , 0
# v:  32 , 0
# v:  33 , 0
# v:  34 , 0
# v:  35 , 0
# v:  36 , 0
# v:  37 , 0
# v:  38 , 0
# v:  39 , 0
# v:  40 , 0
# v:  41 , 0
# v:  42 , 0
# v:  43 , 0
# v:  44 , 0
# v:  45 , 0
# v:  46 , 0
# v:  47 , 0
# v:  48 , 0
# v:  49 , 0
# v:  50 , 0
# v:  51 , 0
# v:  52 , 0
# v:  53 , 0
# v:  54 , 0
# v:  55 , 0
# v:  56 , 0
# v:  57 , 0
# v:  58 , 0
# v:  59 , 0
# v:  60 , 0
# v:  61 , 0
# v:  62 , 0
# v:  63 , 0
# v:  64 , 0
# v:  65 , 0
# v:  66 , 0
# v:  67 , 0
# v:  68 , 0
# v:  69 , 0
# v:  70 , 0
# v:  71 , 0
# v:  72 , 0
# v:  73 , 0
# v:  74 , 0
# v:  75 , 0
# v:  76 , 0
# ...

# %%
h = 0

def dsd():
    for i in range(10):
        if i == 5 :
            h = 5
    print(h)
    
dsd()
# Out:
# 5
